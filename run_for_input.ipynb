# %%
# !pip install scipy
# !pip install seaborn
# !pip install matplotlib
# !pip install spacy
# !pip install scikit-learn

# %%
import numpy as np
from numpy.linalg import norm

from llama_cpp.llama import Llama, LlamaGrammar
from langchain.embeddings import LlamaCppEmbeddings

import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))    

# load input/educations.csv into pandas
df = pd.read_csv("input/educations.csv")

# randomise the order of the rows
# df = df.sample(frac=1, random_state=42).reset_index(drop=True)

df.head()
# Out:
#                        EducationTitle  \
# 0         Spanish Language Essentials
# 1            Photography Fundamentals
# 2       Healthy Cooking for Beginners
# 3           Introduction to Astronomy
# 4  Introduction to Sustainable Living
#
#                                          Description  Duration  \
# 0  Immerse yourself in the basics of Spanish lang...   6 weeks
# 1  Learn the art of photography, including camera...   8 weeks
# 2  Discover the fundamentals of healthy cooking, ...  10 weeks
# 3  Explore the wonders of the universe, covering ...  12 weeks
# 4  Gain insights into sustainable practices, incl...   8 weeks
#
#                                       SkillsAcquired         Level
# 0   Spanish Vocabulary;Grammar;Conversational Skills      Beginner
# 1          Camera Settings;Composition;Photo Editing  Intermediate
# 2      Meal Planning;Nutrition Basics;Cooking Skills      Beginner
# 3  Astronomy Basics;Stargazing Techniques;Celesti...      Beginner
# 4  Sustainable Living Practices;Environmental Awa...      Beginner

# %%
ggml_model_path = "https://huggingface.co/TheBloke/dolphin-2.6-mistral-7B-dpo-laser-GGUF/resolve/main/dolphin-2.6-mistral-7b-dpo-laser.Q4_K_M.gguf"
filename = "input/dolphin-2.6-mistral-7b-dpo-laser.Q4_K_M.gguf"

llm = LlamaCppEmbeddings(model_path=filename)
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 0 | VSX = 0 |

# %%
def embed_row(i, df):
    input_text = df['SkillsAcquired'][i]
    filtered_list = []
    for w in input_text.split():
        if w.lower() not in stop_words:
            filtered_list.append(w.lower())
    filter_input_text = " ".join(filtered_list)
    input = f"""{filter_input_text}""".replace(";", " ")
    print(f"Index {i} - {len(df)}: {input}")
    return llm.embed_query(input)

# %%
def generate_embeddings_with_checkpoints(df, embed_function, checkpoint_interval=10, checkpoint_path="embeddings_checkpoint.pkl"):
    embeddings = []
    checkpoint_index = 0

    # randomise the dataframe rows
    df = df.sample(frac=1).reset_index(drop=True)

    # Attempt to load from checkpoint if exists
    try:
        with open(checkpoint_path, 'rb') as file:
            embeddings, checkpoint_index = pickle.load(file)
            print(f"Resuming from checkpoint at index {checkpoint_index}")
    except FileNotFoundError:
        print("No checkpoint found, starting from scratch")

    # Adjust the loop to iterate over DataFrame rows
    for i in df.index[checkpoint_index:]:
        # Assuming embed_row correctly handles DataFrame rows
        embeddings.append(embed_function(i, df))

        # Save a checkpoint every 'checkpoint_interval' iterations
        if (len(embeddings) % checkpoint_interval == 0) or (i == df.index[-1]):
            with open(checkpoint_path, 'wb') as file:
                pickle.dump((embeddings, i + 1), file)
                print(f"Checkpoint saved at index {i + 1}")

    return embeddings

# %%
embeddings = generate_embeddings_with_checkpoints(df, embed_row, checkpoint_interval=10, checkpoint_path="input/embeddings_checkpoint_skills.pkl")
# Out:
# No checkpoint found, starting from scratch
# Index 0 - 308: Portuguese Language Immersion Portuguese Conversational Skills Grammar Regional Accents
# Index 1 - 308: Introduction to Data Visualization with D3.js D3.js Data Binding SVG Graphics Interactive Data Visualizations
# Index 2 - 308: Learn to Play Chess Chess Rules Chess Strategies Tactical Maneuvers
# Index 3 - 308: Introduction to Storyboarding for Animation Visual Storytelling for Animation Character Design Scene Composition for Animation
# Index 4 - 308: Introduction to Social Psychology Social Behavior Attitudes Group Dynamics Social Psychology Basics
# Index 5 - 308: Mandarin Chinese Film Analysis Chinese Film Analysis Mandarin for Film Critics Cinematic Terminology
# Index 6 - 308: Introduction to Indoor Gardening Indoor Plant Care Container Gardening Herb Cultivation
# Index 7 - 308: Introduction to American Sign Language (ASL) ASL Vocabulary Sign Language Grammar Conversational ASL
# Index 8 - 308: Artificial Intelligence Ethics AI Ethics Responsible AI Bias Detection
# Index 9 - 308: Introduction to Renewable Energy Renewable Energy Basics Solar Power Systems Wind Energy
# Checkpoint saved at index 10
# Index 10 - 308: Italian Opera: Advanced Performance Advanced Opera Performance Italian Language for Opera Singers Operatic Interpretation
# Index 11 - 308: Brazilian Carnival Samba: Performance Advanced Samba Performance Portuguese for Samba Dancers Carnaval Culture
# Index 12 - 308: Chinese Martial Arts Philosophy Chinese Martial Arts Philosophy Ancient Texts Martial Principles
# Index 13 - 308: Arabic Islamic Art and Architecture Arabic Art and Architecture Islamic Art Principles Historical Context
# Index 14 - 308: Egyptian Arabic for Travelers Travel Arabic Phrases Cultural Awareness Egyptian Customs
# Index 15 - 308: Introduction to Cybersecurity Network Security Basics Cryptography Ethical Hacking Fundamentals
# Index 16 - 308: Introduction to Artificial Intelligence for Beginners Artificial Intelligence Basics Machine Learning Applications
# Index 17 - 308: Introduction to Data Science Data Analysis Statistics Machine Learning
# Index 18 - 308: Introduction to Ethical Hacking Ethical Hacking Principles Penetration Testing Network Security
# Index 19 - 308: Introduction to UX Design UX Design Principles User Research Prototyping
# Checkpoint saved at index 20
# Index 20 - 308: Introduction to Sustainable Living Sustainable Living Practices Environmental Awareness Green Energy
# Index 21 - 308: Korean Pop Culture and Language Korean Language Basics K-pop Culture Cultural References
# Index 22 - 308: Introduction to Organic Chemistry Organic Chemistry Basics Molecular Structures Chemical Reactions
# Index 23 - 308: Effective Communication in the Workplace Workplace Collaboration Skills Conflict Resolution Professional Etiquette
# Index 24 - 308: Introduction to DIY Home Automation DIY IoT Devices Smart Home Integration Home Automation Solutions
# Index 25 - 308: Advanced Data Analysis with Python Advanced Python Libraries Data Wrangling Time Series Analysis
# Index 26 - 308: Introduction to Cognitive Behavioral Therapy (CBT) CBT Fundamentals Cognitive Restructuring Behavior Analysis
# Index 27 - 308: Introduction to Artificial Intelligence Machine Learning Deep Learning Neural Networks
# Index 28 - 308: Korean Kimchi Making and Language Korean Kimchi Recipes Cooking Vocabulary Culinary Techniques
# Index 29 - 308: Introduction to Data Science Data Analysis Statistics Machine Learning
# Checkpoint saved at index 30
# Index 30 - 308: Japanese Pottery and Language Japanese Pottery Techniques Pottery Vocabulary Cultural Insights
# Index 31 - 308: Introduction to Mind-Body Wellness Yoga for Wellness Meditation Techniques Holistic Health Practices Wellness Fundamentals
# Index 32 - 308: Introduction to Game Development with Unity Game Design Principles Unity Basics Building Simple Games
# Index 33 - 308: Introduction to DIY Natural Beauty Products Natural Beauty Product Ingredients Formulations for DIY Beauty Products DIY Beauty Product Creation Techniques
# Index 34 - 308: Spanish Language Essentials Spanish Vocabulary Grammar Conversational Skills
# Index 35 - 308: Introduction to Data Visualization with Tableau Data Visualization Techniques Tableau Software Interactive Dashboards
# Index 36 - 308: Introduction to Mobile Game Development with Unity Mobile Game Design Unity Game Development Game Optimization
# Index 37 - 308: Artificial Intelligence in Business  Predictive Analytics Natural Language Processing Machine Learning in Business
# Index 38 - 308: Introduction to Personality Psychology Personality Psychology Theories Personality Assessments Personality Traits
# Index 39 - 308: Digital Marketing Essentials Digital Marketing Strategy Social Media Marketing SEO
# Checkpoint saved at index 40
# Index 40 - 308: Brazilian Carnaval Samba and Portuguese Brazilian Carnaval Samba Portuguese for Samba Dancers Carnaval Culture
# Index 41 - 308: Japanese Sushi Masterclass Sushi Making Techniques Ingredient Selection Sushi Presentation
# Index 42 - 308: Spanish Cuisine: Gourmet Chef Training Advanced Culinary Techniques Gourmet Cooking Skills Spanish Gastronomy
# Index 43 - 308: Introduction to Culinary Arts Culinary Techniques Flavor Pairing Art of Plating
# Index 44 - 308: Introduction to Astronomy for Kids Space Exploration Basics Basic Celestial Observations Solar System Knowledge
# Index 45 - 308: Introduction to 3D Printing 3D Printing Basics 3D Modeling Printer Operation
# Index 46 - 308: Russian History and Politics Russian History Overview Political Developments Cultural Impact
# Index 47 - 308: Introduction to Interior Design Space Planning Color Theory Interior Design Basics
# Index 48 - 308: Introduction to Urban Sketching Sketching Techniques Perspective Drawing Capturing Urban Scenes
# Index 49 - 308: Introduction to User Experience (UX) Design UX Design Principles User Research Wireframing
# Checkpoint saved at index 50
# Index 50 - 308: German Language and Culture German Language Basics Cultural Traditions German History
# Index 51 - 308: Introduction to Augmented Reality Development AR Concepts AR Frameworks Building Simple AR Applications
# Index 52 - 308: Introduction to UX Writing UX Writing Fundamentals Content Strategy Microcopy User-Centric Interfaces
# Index 53 - 308: Introduction to Quantum Computing Quantum Computing Basics Quantum Gates Quantum Algorithms Quantum Information
# Index 54 - 308: Introduction to Robotics for Kids Basic Robotics Concepts Programming Robots Hands-On Robot Building
# Index 55 - 308: Spanish for Marketing Professionals Marketing Spanish Vocabulary Advertising Techniques Market Research
# Index 56 - 308: Mobile App Design with Sketch Mobile UI/UX Design Prototyping with Sketch App Design Principles
# Index 57 - 308: DIY Home Repairs and Maintenance Home Repair Techniques Plumbing Basics Electrical Maintenance
# Index 58 - 308: Korean Taekwondo Korean Taekwondo Forms Sparring Techniques Taekwondo Philosophy
# Index 59 - 308: Healthy Cooking for Beginners Meal Planning Nutrition Basics Cooking Skills
# Checkpoint saved at index 60
# Index 60 - 308: Creative Smartphone Photography Smartphone Photography Techniques Mobile Editing Apps Composition for Mobile Photography
# Index 208 - 308: Arabic Culinary Delights Arabic Cooking Techniques Traditional Dishes Culinary Vocabulary
# Index 209 - 308: Introduction to Cryptography Cryptography Fundamentals Encryption Techniques Cryptographic Protocols
# Checkpoint saved at index 210
# Index 210 - 308: Korean Language for K-drama Enthusiasts Korean Language Basics K-drama Dialogue Cultural References
# Index 211 - 308: Introduction to Bioinformatics Analysis Bioinformatics Sequence Alignment Genomics Analysis Computational Biology
# Index 212 - 308: Spanish Flamenco Dance Flamenco Dance Techniques Choreography Spanish Language Enhancement
# Index 213 - 308: Spanish Wine and Tapas Pairing Spanish Wine and Tapas Pairing Wine Tasting Techniques Spanish Culinary Vocabulary
# Index 214 - 308: Introduction to DIY Woodworking Woodworking Tool Usage Joinery Techniques Building Simple Woodworking Projects
# Index 215 - 308: Introduction to Environmental Science Environmental Science Fundamentals Ecosystem Analysis Conservation Practices
# Index 216 - 308: Arabic Calligraphy and Islamic Art Arabic Calligraphy Styles Islamic Art History Artistic Expression
# Index 217 - 308: Introduction to Blockchain Blockchain Fundamentals Cryptocurrency Smart Contracts
# Index 218 - 308: Web Development Bootcamp HTML CSS JavaScript Web Development
# Index 219 - 308: Introduction to Graphic Novels Graphic Novel Storytelling Character Design Creative Process in Graphic Novel Creation
# Checkpoint saved at index 220
# Index 220 - 308: Spanish Cuisine: Paella Mastery Spanish Paella Cooking Culinary Vocabulary Spanish Gastronomy
# Index 221 - 308: Mindfulness Meditation for Stress Relief Mindfulness Meditation Techniques Stress Management Relaxation Skills
# Index 222 - 308: Brazilian Portuguese Language and Culture Brazilian Portuguese Vocabulary Cultural Insights Samba Dance Basics
# Index 223 - 308: French Poetry and Language French Poetry Analysis Poetic Forms French Literary Vocabulary
# Index 224 - 308: Machine Learning for Beginners Machine Learning Basics Data Preprocessing Model Evaluation
# Index 225 - 308: Healthy Sleep Habits Sleep Hygiene Importance of Sleep Healthy Sleep Habits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 embeddings_0 = generate_embeddings_with_checkpoints(df, embed_row_0, checkpoint_interval=10, checkpoint_path="embeddings_checkpoint_title_skills.pkl")
#       2 # embeddings_1 = generate_embeddings_with_checkpoints(df, embed_row_1, checkpoint_interval=10, checkpoint_path="embeddings_checkpoint_skills.pkl")
#       3 # embeddings_2 = generate_embeddings_with_checkpoints(df, embed_row_2, checkpoint_interval=10, checkpoint_path="embeddings_checkpoint_full.pkl")
#
# Cell In[4], line 19, in generate_embeddings_with_checkpoints(df, embed_function, checkpoint_interval, checkpoint_path)
#      16 # Adjust the loop to iterate over DataFrame rows
#      17 for i in df.index[checkpoint_index:]:
#      18     # Assuming embed_row correctly handles DataFrame rows
# ---> 19     embeddings.append(embed_function(i, df))
#      21     # Save a checkpoint every 'checkpoint_interval' iterations
#      22     if (len(embeddings) % checkpoint_interval == 0) or (i == df.index[-1]):
#
# Cell In[3], line 4, in embed_row_0(i, df)
#       2 input = f"""{df['EducationTitle'][i]} {df['SkillsAcquired'][i]}""".replace(";", " ")
#       3 print(f"Index {i} - {len(df)}: {input}")
# ----> 4 return llm.embed_query(input)
#
# File c:\Users\skovda93\AppData\Local\anaconda3\envs\hmi\lib\site-packages\langchain\embeddings\llamacpp.py:125, in LlamaCppEmbeddings.embed_query(self, text)
#     116 def embed_query(self, text: str) -> List[float]:
#     117     """Embed a query using the Llama model.
#     118
#     119     Args:
#    (...)
#     123         Embeddings for the text.
#     124     """
# --> 125     embedding = self.client.embed(text)
#     126     return list(map(float, embedding))
#
# File c:\Users\skovda93\AppData\Local\anaconda3\envs\hmi\lib\site-packages\llama_cpp\llama.py:1304, in Llama.embed(self, input)
#    1295 def embed(self, input: str) -> List[float]:
#    1296     """Embed a string.
#    1297
#    1298     Args:
#    (...)
#    1302         A list of embeddings
#    1303     """
# -> 1304     return list(map(float, self.create_embedding(input)["data"][0]["embedding"]))
#
# File c:\Users\skovda93\AppData\Local\anaconda3\envs\hmi\lib\site-packages\llama_cpp\llama.py:1268, in Llama.create_embedding(self, input, model)
#    1266 tokens = self.tokenize(input.encode("utf-8"), special=True)
#    1267 self.reset()
# -> 1268 self.eval(tokens)
#    1269 n_tokens = len(tokens)
#    1270 total_tokens += n_tokens
#
# File c:\Users\skovda93\AppData\Local\anaconda3\envs\hmi\lib\site-packages\llama_cpp\llama.py:1030, in Llama.eval(self, tokens)
#    1026 n_tokens = len(batch)
#    1027 self._batch.set_batch(
#    1028     batch=batch, n_past=n_past, logits_all=self.context_params.logits_all
#    1029 )
# -> 1030 self._ctx.decode(self._batch)
#    1031 # Save tokens
#    1032 self.input_ids[n_past : n_past + n_tokens] = batch
#
# File c:\Users\skovda93\AppData\Local\anaconda3\envs\hmi\lib\site-packages\llama_cpp\llama.py:466, in _LlamaContext.decode(self, batch)
#     464 assert self.ctx is not None
#     465 assert batch.batch is not None
# --> 466 return_code = llama_cpp.llama_decode(
#     467     ctx=self.ctx,
#     468     batch=batch.batch,
#     469 )
#     470 if return_code != 0:
#     471     raise RuntimeError(f"llama_decode returned {return_code}")
#
# File c:\Users\skovda93\AppData\Local\anaconda3\envs\hmi\lib\site-packages\llama_cpp\llama_cpp.py:1193, in llama_decode(ctx, batch)
#    1192 def llama_decode(ctx: llama_context_p, batch: llama_batch) -> int:
# -> 1193     return _lib.llama_decode(ctx, batch)
#
# KeyboardInterrupt:

# %%
# Create an word occurance matrix for each row in the dataset
# each row in the matrix corresponds to a row in the dictionary and each column corresponds to a word in the dictionary
# the value of each cell is the number of times the word appears in the sentence
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))

def get_word_occurrence_matrix(data):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(data)
    df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
    return df

def filter_out_stopwords(query):
    filtered_list = []
    for w in query.split():
        if w.lower() not in stop_words:
            filtered_list.append(w.lower())
    filtered_query = " ".join(filtered_list)
    return filtered_query

# %%
# Create a word occurance matrix for the dataset
data = pd.read_csv("input/educations.csv")
# create a list of a concatenation of the title and description
data["Temp"] = data["EducationTitle"] + "; " + data["SkillsAcquired"]
# filter out stopwords
data["Temp"] = data["Temp"].apply(filter_out_stopwords)
data = data["Temp"].tolist()
df = get_word_occurrence_matrix(data)
df.to_csv("input/word_matrix.csv", index=False)
